# %% [markdown]
# # Load Pacakages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mglearn
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
pvt = pd.pivot_table(df,
    values='mean_test_score', index='param_KNN__n_neighbors', columns='param_SMOTE__sampling_strategy')

ax = sns.heatmap(pvt,annot=True,cmap='YlGnBu')

# %%
df = pd.read_csv('C:/Users/koyounghun/Desktop/찌르레기/Loan_data/grid/KNN_ADA.csv')


df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       4.272000      0.230161         1.870799        0.058602
# 1       4.579205      0.249765         2.143795        0.206615
# 2       4.137798      0.341964         2.069002        0.098187
# 3       4.040599      0.163055         2.133402        0.157642
# 4       4.085800      0.312951         2.348199        0.313898
#
#    param_ADASYN__sampling_strategy  param_KNN__n_neighbors  \
# 0                              0.5                      10
# 1                              0.5                      20
# 2                              0.5                      30
# 3                              0.5                      40
# 4                              0.5                      50
#
#                                               params  split0_test_score  \
# 0  {'ADASYN__sampling_strategy': 0.5, 'KNN__n_nei...           0.833235
# 1  {'ADASYN__sampling_strategy': 0.5, 'KNN__n_nei...           0.847232
# ...

# %%
pvt = pd.pivot_table(df,
    values='mean_test_score', index='param_KNN__n_neighbors', columns='param_ADASYN__sampling_strategy')

ax = sns.heatmap(pvt,annot=True,cmap='YlGnBu')

# %%
df = pd.read_csv('C:/Users/koyounghun/Desktop/찌르레기/Loan_data/grid/KNN_SVR.csv')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.169583      0.026595         1.337671        0.046761
# 1       3.089386      0.077416         1.375645        0.043555
# 2       3.951481      0.029676         1.368517        0.032820
# 3       2.151564      0.022507         1.384901        0.018670
# 4       3.045727      0.030319         1.404996        0.009386
#
#    param_KNeighborsClassifier__n_neighbors  param_SVR__proportion  \
# 0                                       10                   0.50
# 1                                       10                   0.75
# 2                                       10                   1.00
# 3                                       20                   0.50
# 4                                       20                   0.75
#
#                                               params  split0_test_score  \
# 0  {'KNeighborsClassifier__n_neighbors': 10, 'SVR...           0.726290
# ...

# %%
pvt = pd.pivot_table(df,
    values='mean_test_score', index='param_KNeighborsClassifier__n_neighbors', columns='param_SVR__proportion')

ax = sns.heatmap(pvt,annot=True,cmap='YlGnBu')

# %%
df = pd.read_csv('C:/Users/koyounghun/Desktop/찌르레기/Loan_data/grid/RF_SMOTE.csv')


df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      23.294585      0.244121         1.055270        0.071276
# 1      27.892701      0.300375         1.037567        0.010340
# 2      32.595031      0.260137         1.074442        0.013818
# 3      45.858680      0.324354         1.983374        0.008340
# 4      53.168388      0.048350         2.012800        0.015188
#
#    param_RandomForestClassifier__n_estimators  param_SMOTE__sampling_strategy  \
# 0                                         100                            0.50
# 1                                         100                            0.75
# 2                                         100                            1.00
# 3                                         200                            0.50
# 4                                         200                            0.75
#
#                                               params  split0_test_score  \
# ...

# %%
pvt = pd.pivot_table(df,
    values='mean_test_score', index='param_RandomForestClassifier__n_estimators', columns='param_SMOTE__sampling_strategy')

ax = sns.heatmap(pvt,annot=True,cmap='YlGnBu')
